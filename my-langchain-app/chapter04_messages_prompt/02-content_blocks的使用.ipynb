# %% [markdown]
# # 1、content的使用
#
# 举例1：保存多模态的数据，使用字典列表

# %%
import base64
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv(override=True)

# model = init_chat_model(
#     model="gpt-5.4-mini",
#     model_provider="openai",
#     api_key=os.getenv("CLOSEAI_API_KEY"),
#     base_url=os.getenv("CLOSEAI_BASE_URL")
# )
model = init_chat_model(
    model="glm-4v-flash",
    model_provider="openai",
    #temperature=1.5,
    api_key=os.getenv("ZHIPUAI_API_KEY"),
    base_url=os.getenv("ZHIPUAI_BASE_URL"),
)

def encode_image(img_path, img_type='jpeg'):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode('utf-8')}"

# 图像路径
img_path = "image_test.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        HumanMessage(
            content=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image_url',
                    "image_url": {"url": base64_image},
                }
            ]
        )
    ]
)
print(response.content)
# Out:
# 图片中展示的是一个香水瓶子，瓶身呈淡粉色，上面有一个金色的标签和盖子。瓶子上有一些文字，但不够清晰无法辨认。背景是浅黄色的。

# %% [markdown]
# # 2、content_blocks的使用
#
# 举例1 ：输入的格式化

# %%
from langchain.messages import HumanMessage
import os
from dotenv import load_dotenv

load_dotenv(override=True)

# model = init_chat_model(
#     model="gpt-5.4-mini",
#     model_provider="openai",
#     api_key=os.getenv("CLOSEAI_API_KEY"),
#     base_url=os.getenv("CLOSEAI_BASE_URL")
# )
model = init_chat_model(
    model="glm-4v-flash",
    model_provider="openai",
    #temperature=1.5,
    api_key=os.getenv("ZHIPUAI_API_KEY"),
    base_url=os.getenv("ZHIPUAI_BASE_URL"),
)

def encode_image(img_path):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# 图像路径
img_path = "image_test.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        # 此种格式可用
        # HumanMessage(
        #     content=[
        #         {'type': 'text', 'text': '这张图里有什么？'},
        #         {
        #             'type': 'image_url',
        #             "image_url": base64_image,
        #         }
        #     ]
        # )
        # 推荐的统一写法
        HumanMessage(
            content_blocks=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image',
                    'base64': base64_image,
                    'mime_type': 'image/png',
                }
            ]
        )

    ]
)
print(response.content)
# Out:
# 图片中展示的是一瓶香水瓶，瓶身是透明的，可以看到里面的液体，瓶盖是金色的，上面有金色和黑色的标签。背景是浅黄色。

# %% [markdown]
# 作为对比

# %%
import base64
from langchain.messages import HumanMessage

from dotenv import load_dotenv
load_dotenv(override=True)

model = init_chat_model(
    model="claude-haiku-4-5",
    model_provider="openai",
    api_key=os.getenv("CLOSEAI_API_KEY"),
    base_url=os.getenv("CLOSEAI_BASE_URL")
)

def encode_image(img_path):
    """将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据"""
    with open(img_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode("utf-8")

# 图像路径
img_path = "image_test.png"

# 获取图像base64编码字符串
base64_image = encode_image(img_path)

response = model.invoke(
    [
        # 传统的写法：使用content。读取失败
        # HumanMessage(
        #     content=[
        #         {'type': 'text', 'text': '这张图里有什么？'},
        #         {
        #             'type': 'image_url',
        #             "image_url": base64_image,
        #         }
        #     ]
        # )

        # 推荐的统一写法
        HumanMessage(
            content_blocks=[
                {'type': 'text', 'text': '这张图里有什么？'},
                {
                    'type': 'image',
                    'base64': base64_image,
                    'mime_type': 'image/png',
                }
            ]
        )
    ]
)
print(response.content)
# Out:
# 这张图里是一瓶**香水或液体化妆品**。具体特点包括：
#
# - **瓶身**：透明玻璃瓶，呈方形或矩形设计
# - **颜色**：液体呈浅金色或米色
# - **瓶盖**：金色的喷雾泵头或压泵设计
# - **风格**：高级、精致的美妆产品包装
# - **背景**：米色/奶油色背景，光线充足
#
# 从外观推测，这可能是：
# - 香水
# - 粉底液
# - 妆前乳或定妆喷雾
# - 其他高端护肤/彩妆产品
#
# 整个画面呈现出专业的产品摄影风格，强调产品的质感和高级感。

# %% [markdown]
# 举例2：输出的格式化

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
load_dotenv()

load_dotenv(override=True)

# model = init_chat_model(
#     model="deepseek:deepseek-v4-flash",
#     extra_body={"thinking": {"type": "enabled"}},
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    extra_body={"thinking": {"type": "enabled"}},
)
# print('-' * 40)
# thinking_printed = False
# for chunk in model.stream("解释什么是人工智能"):
#     thinking = chunk.additional_kwargs.get("reasoning_content")
#     if thinking:
#         if not thinking_printed:
#             print("\n🤔 思考过程：\n", end="")
#             thinking_printed = True
#         print(thinking, end="", flush=True)
#
#     if chunk.content:
#         if thinking_printed:
#             print("\n\n💬 回答：\n", end="")
#             thinking_printed = False
#         print(chunk.content, end="", flush=True)
#
# print('-' * 40)


response = model.invoke("你好，一句话回答")
print('=' * 20, '-> response <-', '=' * 20)
print(response)
print('=' * 20, '-> response.content <-', '=' * 20)
print(response.content)
print('=' * 20, '-> response.content_blocks <-', '=' * 20)
print(response.content_blocks)
# Out:
# ----------------------------------------
#
# 🤔 思考过程：
# 用户问的是人工智能的基本概念。这个问题比较基础但重要，需要给出清晰准确的定义，同时要避免过于技术化。可以从AI的本质、核心能力、常见应用场景和主要技术分支这几个方面来组织回答。先给出一个通俗易懂的定义，说明AI是模拟人类智能的技术。然后解释它能做什么，比如学习、推理、感知等。再列举一些日常生活中接触到的AI例子，让用户更好理解。最后可以简要提一下目前AI的主要技术方向，比如机器学习、深度学习、自然语言处理等。这样结构比较完整，从抽象概念到具体应用，再到技术实现，层层递进。需要注意用词要平实，避免让不熟悉技术的用户感到困惑。
#
# 💬 回答：
# 人工智能（AI）是计算机科学的一个分支，旨在创建能够模拟人类智能的机器或系统。简单来说，它让计算机能够像人一样思考、学习、推理和解决问题。
#
# 它的核心能力包括：
# - **学习**：从数据中提取规律（比如通过大量图片学会识别猫）。
# - **推理**：根据已知信息得出结论（比如诊断疾病）。
# - **感知**：理解图像、声音、文字等外部信息。
# - **决策**：在复杂环境中采取最优行动（比如自动驾驶避让行人）。
#
# 你每天都会接触AI：语音助手（Siri）、推荐算法（抖音、淘宝）、人脸识别（手机解锁）、机器翻译（谷歌翻译）等等。
#
# ### 当前AI的主要方向
# - **机器学习**：让计算机从数据中自动学习，而非明确编程。
# - **深度学习**：通过多层神经网络处理复杂问题（如识别X光片中的肿瘤）。
# - **自然语言处理**：让计算机理解并生成人类语言（如ChatGPT）。
# - **计算机视觉**：让计算机“看懂”图像和视频（如自动驾驶中的障碍物检测）。
#
# ### 关键区分
# - **弱AI**：专注于单一任务（如AlphaGo只会下围棋，不能做饭）。
# - **强AI**：具备通用智能，能像人类一样处理各种问题（目前未实现）。
#
# AI的本质是**模拟智能的工具**，它的发展依赖数据、算法和算力三者的结合。未来，AI将在医疗、气候预测、教育等领域带来颠覆性变革，但也伴随着伦理、隐私和就业等挑战需要谨慎应对。----------------------------------------
# ==================== -> response <- ====================
# content='你好，随时可以问我任何问题。' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户只是简单问候并希望一句话回答。这很直接，不需要复杂分析。核心就是简洁回应，同时保持友好开放，让用户知道可以随时提问。就用“你好，随时可以问我任何问题。”这样既礼貌又明确服务范围。'} response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 8, 'total_tokens': 71, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 54, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '43884647-3d9b-4e00-8ddb-b43b38b0e4f3', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f5585-ea86-7571-9ffc-d8aada3185a6-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 63, 'total_tokens': 71, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 54}}
# ==================== -> response.content <- ====================
# 你好，随时可以问我任何问题。
# ==================== -> response.content_blocks <- ====================
# [{'type': 'reasoning', 'reasoning': '好的，用户只是简单问候并希望一句话回答。这很直接，不需要复杂分析。核心就是简洁回应，同时保持友好开放，让用户知道可以随时提问。就用“你好，随时可以问我任何问题。”这样既礼貌又明确服务范围。'}, {'type': 'text', 'text': '你好，随时可以问我任何问题。'}]

# %% [markdown]
# # tool_choice的使用
#
# ## 1、tool_choice的取值为none

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

# 从.env文件中加载环境变量
load_dotenv(override=True)

# CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
# CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")
#
# model = init_chat_model(
#     model="gpt-5.4-mini",
#     model_provider="openai",
#     api_key=CLOSEAI_API_KEY,
#     base_url=CLOSEAI_BASE_URL
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    extra_body={"thinking": {"type": "disabled"}},
)

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather],tool_choice="none")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='我现在无法直接获取北京的实时天气信息。  \n如果你愿意，我可以帮你：\n\n-
# 根据北京当前季节，给你一个大致天气预期\n- 告诉你今天出门适合穿什么\n-
# 帮你整理一个查看实时天气的简单方法\n\n如果你想，我也可以直接给你一份“北京今天出行穿搭建议”。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 87,
#             'prompt_tokens': 134,
#             'total_tokens': 221,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 29,
#                 'engine_ttlt_ms': 404,
#                 'pre_inference_ms': 131,
#                 'service_tbt_ms': 4,
#                 'service_ttft_ms': 321,
#                 'service_ttlt_ms': 691,
#                 'total_duration_ms': 566,
#                 'user_visible_ttft_ms': 190
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'gpt-5.4-mini-2026-03-17',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-DkW0J3E0BVHMfKjInUSZDH2ldqFwT',
#         'service_tier': 'default',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='lc_run--019e6efc-2ea7-7272-ab24-a8fba54b6fe2-0',
#     tool_calls=[],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 134,
#         'output_tokens': 87,
#         'total_tokens': 221,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %% [markdown]
# ## 2、tool_choice的取值为auto

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather],tool_choice="auto")

response = model_with_tools.invoke("北京今天的天气如何？")
#response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='好的，我来查询一下北京今天的天气情况。',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 54,
#             'prompt_tokens': 282,
#             'total_tokens': 336,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 26
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '7886a1c9-0c7b-42c0-8104-c8ffe2e92d0e',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019f6618-4aa3-7dc1-a58a-f085a00c8afe-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_00_FgdSkv6iIs330fqpB4aS8770',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 282,
#         'output_tokens': 54,
#         'total_tokens': 336,
#         'input_token_details': {'cache_read': 256},
#         'output_token_details': {}
#     }
# )

# %% [markdown]
# ## 3、tool_choice取值为required

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 37,
#             'prompt_tokens': 289,
#             'total_tokens': 326,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 33
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '67b748f5-08f0-400a-a1d7-630660d83d2b',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019f6617-3e4b-7161-8958-b5ce9d8340e7-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_00_qVffR2hzphXvC3hhf2td1791',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 289,
#         'output_tokens': 37,
#         'total_tokens': 326,
#         'input_token_details': {'cache_read': 256},
#         'output_token_details': {}
#     }
# )

# %%
from langchain.tools import tool
from rich import print as rprint

@tool(parse_docstring=True)
def get_weather(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather],tool_choice="required")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 37,
#             'prompt_tokens': 292,
#             'total_tokens': 329,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256},
#             'prompt_cache_hit_tokens': 256,
#             'prompt_cache_miss_tokens': 36
#         },
#         'model_provider': 'deepseek',
#         'model_name': 'deepseek-v4-flash',
#         'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402',
#         'id': '71f5a81c-1680-4f53-b6cf-15c3f9cefc04',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019f6617-c052-7962-9c7f-cdc9e40ac628-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '上海'},
#             'id': 'call_00_aG4EvOsKTz48yk05MU353282',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 292,
#         'output_tokens': 37,
#         'total_tokens': 329,
#         'input_token_details': {'cache_read': 256},
#         'output_token_details': {}
#     }
# )

# %% [markdown]
# ## 4、强制调用指定的工具

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather1,get_weather2],tool_choice="get_weather2")

response = model_with_tools.invoke("2 + 3 = ?")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 19,
#             'prompt_tokens': 160,
#             'total_tokens': 179,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 33,
#                 'engine_ttlt_ms': 110,
#                 'pre_inference_ms': 141,
#                 'service_tbt_ms': 4,
#                 'service_ttft_ms': 331,
#                 'service_ttlt_ms': 402,
#                 'total_duration_ms': 271,
#                 'user_visible_ttft_ms': 190
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'gpt-5.4-mini-2026-03-17',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-DkW4qCfnUr26R5eqQGqG4l9qqSJHI',
#         'service_tier': 'default',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019e6f00-76dd-7653-bfae-806225488309-0',
#     tool_calls=[
#         {
#             'name': 'get_weather2',
#             'args': {'city': '北京'},
#             'id': 'call_b4ybyM9wBpH1EcxqRbvfxnk4',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 160,
#         'output_tokens': 19,
#         'total_tokens': 179,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

# %%
from langchain.tools import tool
from langchain.messages import HumanMessage


@tool(parse_docstring=True)
def get_weather1(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'

@tool(parse_docstring=True)
def get_weather2(city: str) -> str:
    """
    获取当日天气

    Args:
        city: 城市名称
    """
    return f'{city}当天晴朗'


model_with_tools = model.bind_tools([get_weather1,get_weather2],tool_choice="get_weather1")

response = model_with_tools.invoke("北京今天的天气如何？")
rprint(response)
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 19,
#             'prompt_tokens': 160,
#             'total_tokens': 179,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': 0,
#                 'audio_tokens': 0,
#                 'reasoning_tokens': 0,
#                 'rejected_prediction_tokens': 0
#             },
#             'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0},
#             'latency_checkpoint': {
#                 'engine_tbt_ms': 4,
#                 'engine_ttft_ms': 39,
#                 'engine_ttlt_ms': 110,
#                 'pre_inference_ms': 79,
#                 'service_tbt_ms': 5,
#                 'service_ttft_ms': 298,
#                 'service_ttlt_ms': 388,
#                 'total_duration_ms': 318,
#                 'user_visible_ttft_ms': 220
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'gpt-5.4-mini-2026-03-17',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-DkW5Vscfe05hF5f5n69WlSySMJ6Ak',
#         'service_tier': 'default',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--019e6f01-17f7-7003-ad0a-29486f826625-0',
#     tool_calls=[
#         {
#             'name': 'get_weather1',
#             'args': {'city': '北京'},
#             'id': 'call_zd392cpyDXgjgUwczQzQ2QQa',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 160,
#         'output_tokens': 19,
#         'total_tokens': 179,
#         'input_token_details': {'audio': 0, 'cache_read': 0},
#         'output_token_details': {'audio': 0, 'reasoning': 0}
#     }
# )

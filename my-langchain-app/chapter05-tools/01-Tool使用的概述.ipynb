# %% [markdown]
# # Tool使用的概述
#
# ## 1、工具的调用方式
#
# ### 1.1 方式1：直接调用

# %%
from langchain_core.tools import tool

@tool
def get_weather(city: str) -> str:
    """
    获取指定城市的天气信息

    参数:
        city: 城市名称，如"北京"、"上海"

    返回:
        天气信息字符串
    """
    # 你的实现
    return city + "晴天，温度 15°C"

# %%
get_weather.invoke({"city":"北京"})
# Out:
# '北京晴天，温度 15°C'

# %% [markdown]
# ### 1.2 方式2：基于模型进行调用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os


# 从.env文件中加载环境变量
load_dotenv(override=True)
#
# CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
# CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")
#
# model = init_chat_model(
#     model="gpt-5.4-mini",
#     model_provider="openai",
#     api_key=CLOSEAI_API_KEY,
#     base_url=CLOSEAI_BASE_URL
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
)

# %%
from langchain_core.tools import tool

# 定义工具
@tool
def get_weather(city: str) -> str:
    """获取指定城市的天气"""
    # 你的实现
    return "晴天，温度 15°C"


# 绑定工具
model_with_tools = model.bind_tools([get_weather])

# AI 可以决定是否调用工具
response = model_with_tools.invoke("北京天气如何？")
# response = model_with_tools.invoke("2 + 3 = ？")

# 检查 AI 是否要调用工具
if response.tool_calls:
    print("AI 想调用工具：", response.tool_calls)
else:
    print("AI 直接回答：", response.content)
# Out:
# AI 想调用工具： [{'name': 'get_weather', 'args': {'city': '北京'}, 'id': 'call_00_RwAh7d6ekloTQ5gyBPlq7455', 'type': 'tool_call'}]

# %% [markdown]
# ## 2、从Message流转看工具的调用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os

# 从.env文件中加载环境变量
load_dotenv(override=True)

# CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
# CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")
#
# model = init_chat_model(
#     model="gpt-5.4-mini",
#     model_provider="openai",
#     api_key=CLOSEAI_API_KEY,
#     base_url=CLOSEAI_BASE_URL
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
)

# %% [markdown]
# ### 2.1 工具的调用方式1：直接调用
#
# 不用 tool 修饰

# %%
from langchain.messages import HumanMessage, ToolMessage
from rich import print as rprint


def get_weather(city: str):
    """获取天气的工具"""
    return f"{city}天气晴朗~"


# 将模型和工具绑定
model_with_tools = model.bind_tools([get_weather])

# 声明一个消息列表
messages = [
    HumanMessage("今天北京天气如何")
]

# 模型生成调用工具请求
response = model_with_tools.invoke(messages)

# 添加AIMessage到消息列表中
messages.append(response)

# rprint(response)

tool_calls = response.tool_calls

for tool_call in tool_calls:
    if tool_call["name"] == "get_weather":
        # 拼接出ToolMessage实例
        tool_response = ToolMessage(
            content=get_weather(tool_call["args"]),
            tool_call_id=tool_call["id"],
            name=tool_call["name"]
        )
        print(type(tool_response))
        messages.append(tool_response)

print("=====================> messages <=====================")
for msg in messages:
    msg.pretty_print()
print("=====================> messages <=====================")
final_response = model_with_tools.invoke(messages)
print(f"final_response: \n{final_response}")
# Out:
# <class 'langchain_core.messages.tool.ToolMessage'>
# =====================> messages <=====================
# ================================ Human Message =================================
#
# 今天北京天气如何
# ================================== Ai Message ==================================
# Tool Calls:
#   get_weather (call_00_oXaoZuUfATMnUBGkWrfL8074)
#  Call ID: call_00_oXaoZuUfATMnUBGkWrfL8074
#   Args:
#     city: 北京
# ================================= Tool Message =================================
# Name: get_weather
#
# {'city': '北京'}天气晴朗~
# =====================> messages <=====================
# final_response:
# content='今天北京的天气是 **晴朗** 的！☀️ 是个好天气，祝您心情愉快！' additional_kwargs={'refusal': None, 'reasoning_content': '工具返回了北京天气的信息：晴朗。我可以直接告诉用户。'} response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 360, 'total_tokens': 398, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 14, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 104}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '5e07c00e-745c-4004-bf0a-301b0bc25484', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f55e7-b399-71e2-9479-d671d27f83bf-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 360, 'output_tokens': 38, 'total_tokens': 398, 'input_token_details': {'cache_read': 256}, 'output_token_details': {'reasoning': 14}}

# %% [markdown]
# ### 2.2 工具的调用方式2：基于模型进行调用
#
# 使用 @Tool

# %%
from langchain.messages import HumanMessage, ToolMessage
from rich import print as rprint
@tool
def get_weather(city: str):
    """获取天气的工具"""
    return f"{city}天气晴朗~"


# 将模型和工具绑定
model_with_tools = model.bind_tools([get_weather])

# 声明一个消息列表
messages = [
    HumanMessage("今天北京天气如何")
]

# 模型生成调用工具请求
response = model_with_tools.invoke(messages)

# 添加AIMessage到消息列表中
messages.append(response)

# rprint(response)

tool_calls = response.tool_calls

for tool_call in tool_calls:
    if tool_call["name"] == "get_weather":
        # 大模型和Agent的主要区别在于：大模型不会主动的调用工具，所以这时候我们需要主动让工具调用。
        # 返回的是ToolMessage类型消息，添加到消息列表中
        # 说明：被 @tool 修饰的函数可以调用 invoke 接收模型返回的入参信息执行函数，并返回ToolMessage 实例，我们不再需要手动拼接 ToolMessage
        tool_response = get_weather.invoke(tool_call)
        print(type(tool_response))
        messages.append(tool_response)

print("=====================> messages <=====================")
for msg in messages:
    msg.pretty_print()
print("=====================> messages <=====================")
final_response = model_with_tools.invoke(messages)
print(f"final_response: \n{final_response}")
# Out:
# <class 'langchain_core.messages.tool.ToolMessage'>
# =====================> messages <=====================
# ================================ Human Message =================================
#
# 今天北京天气如何
# ================================== Ai Message ==================================
# Tool Calls:
#   get_weather (call_00_v6ERjCU576GonTMDtFL10079)
#  Call ID: call_00_v6ERjCU576GonTMDtFL10079
#   Args:
#     city: 北京
# ================================= Tool Message =================================
# Name: get_weather
#
# 北京天气晴朗~
# =====================> messages <=====================
# final_response:
# content='今天北京的天气是**晴朗**的！☀️\n\n天气不错，适合出门活动或者晒晒太阳。不过具体温度和风力等信息我没有获取到，建议你出门前可以再多留意一下实时天气详情哦～' additional_kwargs={'refusal': None, 'reasoning_content': '工具返回了北京天气晴朗的信息。让我告诉用户。'} response_metadata={'token_usage': {'completion_tokens': 58, 'prompt_tokens': 354, 'total_tokens': 412, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 12, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 256}, 'prompt_cache_hit_tokens': 256, 'prompt_cache_miss_tokens': 98}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '969610c4-55e4-4a9f-9479-56cedf5efd38', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f55dd-c9a7-7160-a792-80dab37bdadf-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 354, 'output_tokens': 58, 'total_tokens': 412, 'input_token_details': {'cache_read': 256}, 'output_token_details': {'reasoning': 12}}

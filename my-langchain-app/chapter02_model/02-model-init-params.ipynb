# %% [markdown]
# # 模型初始化的参数使用情况
#
# ## 1、temperature的使用
#
# 举例1

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=0,
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 《春行》
# 山溪涨绿柳垂丝，桃李争妍莺语痴。
# 最是今朝时雨足，扶犁陌上种春诗。
#
# 赏析：这首作品以春天为背景，通过“山溪涨绿”、“柳垂丝”、“桃李争妍”等生动意象，勾勒出一幅生机盎然的春日画卷。诗中“时雨足”、“扶犁陌上”等句，不仅传递出春耕的农事气息，更以“种春诗”的巧妙比喻，将自然之春与人文之诗相融合，表达了对春天深厚的情感与赞美。
# 《春行》
# 二月东风破冻痕，一溪新涨绿初温。
# 桃花未识春深浅，先遣红妆过短垣。
#
# 赏析：这首作品描绘早春景象，以东风解冻、溪水新涨起笔，展现春意初萌的生机。后两句赋予桃花以灵性，通过“未识春深浅”的拟人手法，生动刻画出花儿迫不及待绽放的俏皮情态。全诗语言清丽，意境明快，在传统春景中注入灵动意趣，尤其“红妆过短垣”的结句，将春色突破空间限制的张力表现得淋漓尽致。
# 《七绝·春景》
# 东风拂柳绿初匀，细雨斜飞草色新。
# 戏蝶流连花影乱，娇莺啼破一湖春。
#
# 赏析：这首作品以春日景象为背景，通过“东风拂柳”、“细雨斜飞”等细腻描绘，勾勒出春意盎然的画卷。后两句“戏蝶流连花影乱，娇莺啼破一湖春”，巧妙运用拟人手法，赋予蝶莺以灵性，生动展现春日的生机与活力，表达了对春天美景的无限喜爱。

# %% [markdown]
# 对比：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 获取大模型
model = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    temperature=1.9,
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)

for i in range(3):
    print(model.invoke("帮我写一首关于春天的七言绝句").content)
# Out:
# 《春行》
# 燕剪轻寒入画时，花明柳暗步迟迟。
# 一溪香涨春潮碧，两岸风梳杨柳丝。
#
# 赏析：这首作品描绘春日漫步之景，以“燕剪轻寒”点染早春气息，“花明柳暗”展现色彩层次。后两句通过“香涨春潮”暗喻繁花倒映溪水，而“风梳杨柳”则赋予自然拟人化的柔美动态。全诗通过感官交织（视觉、嗅觉、触觉）与动静相生之笔，勾勒出春意盎然的诗意画卷。
# 《早春即景》
# 东君挥笔点芳枝，万树桃花灼灼时。
# 燕剪新裁杨柳细，一湖春水漾涟漪。
#
# 注：我的仿写思路是紧扣“早春”意象，首句以拟人手法写东风催开百花，次句用“灼灼”突显桃花盛放之态。三句巧用“燕剪”这一经典组合，既状飞燕之态又喻柳叶新裁，尾句铺展春水潋滟之景。全诗通过桃柳燕水的雅致铺陈，展现春意萌动的生机与美感。
# 《七绝·春归》
# 东君送暖入千家，一夜轻雷发万芽。
# 燕剪垂绦穿碧水，春烟漫煮雨前茶。
#
# 赏析：这首作品以“春归”为主题，通过“东君送暖”、“轻雷发万芽”等意象生动展现春回大地的蓬勃生机。后两句“燕剪垂绦穿碧水”巧用比喻，将燕尾比作剪刀，裁出柳丝轻拂碧水的灵动画面；结句“春烟漫煮雨前茶”则巧妙融入江南春茶文化，以氤氲茶香收束全篇，传递出闲适雅致的春日意趣。

# %% [markdown]
# 举例2：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

# 获取大模型
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    temperature=0,
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
)


# 向模型发送单条数据
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response.content)
# Out:
# {
#   "name": "张三",
#   "gender": "男",
#   "age": 30,
#   "yearsOfExperience": 8,
#   "currentPosition": "技术专家",
#   "company": "某互联网大厂"
# }

# %% [markdown]
# 举例3：应用

# %%
from langchain.chat_models import init_chat_model
from dotenv import load_dotenv
import os
# 从.env文件中加载环境变量
load_dotenv(override=True)

model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    temperature=1.5,
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
)

# 向模型发送单条数据
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语。")
print(response.content)
# Out:
# ### 给无声刺客的三行战歌 ###
#
# 1. **当叩问褪去杂音，只剩思想落键的回响。**
#    *内核张力：将“静音”转化为精神触达的哲学表达，暗示键盘是思维投射的纯粹载体。*
#
# 2. **在寂静的锋刃上，敲响未被听闻的惊雷。**
#    *内核张力：用金属诗意解构“静音”，将压感转换为隐于平静的创造力爆破。*
#
# 3. **午夜平行于世界——每个键都是秘密的着陆点。**
#    *内核张力：用空间诗意重构使用场景，把按键动作升维成潜入平行时空的轻秘仪式。*
#
# ---
#
# **隐喻落点说明**：这三组文案放弃了直接描述“静音技术”，转而用**剑、雷鸣、平行时空**等意象构建冲突感——把机械键盘静音的「物理特性」转化为使用者精神世界的「张力现场」，让沉默本身成为最震撼的表达。

# %% [markdown]
# ## 2. max_tokens参数的使用
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
# CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

# 获取大模型
# model = init_chat_model(
#     model="openai:gpt-5.4-mini",
#     # temperature=1.9,
#     api_key=CLOSEAI_API_KEY,
#     base_url=CLOSEAI_BASE_URL,
#     max_tokens=10,
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    #temperature=1.5,
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
    max_tokens=10,
)

print(model.invoke("介绍一下你自己"))
# Out:
# content='' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我介绍一下自己。这是一个简单的自我介绍'} response_metadata={'token_usage': {'completion_tokens': 10, 'prompt_tokens': 6, 'total_tokens': 16, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 10, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': 'c2c4a6d6-dff2-4d5c-aecc-ade3b994bef5', 'finish_reason': 'length', 'logprobs': None} id='lc_run--019f5105-4169-7881-8758-ed3007d9f990-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 10, 'total_tokens': 16, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 10}}

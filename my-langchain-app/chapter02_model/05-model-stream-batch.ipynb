# %% [markdown]
# # 1、流式调用(stream)
#
# 举例：

# %%
from langchain.chat_models import init_chat_model
import os
from dotenv import load_dotenv

# 加载配置文件
load_dotenv(override=True)

# CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
# CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")
#
# # 获取大模型
# model = init_chat_model(
#     model="openai:gpt-5.4-mini",
#     api_key=CLOSEAI_API_KEY,
#     base_url=CLOSEAI_BASE_URL,
# )
model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    #temperature=1.5,
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url=os.getenv("DEEPSEEK_BASE_URL"),
)

# %%
for chunk in model.stream("帮我解释一下什么是人工智能？"):
    print(chunk.text,end="",flush=True)
# Out:
# 当然可以。让我们用最简单、最清晰的方式来理解“人工智能”。
#
# **一句话定义：**
#
# 人工智能（Artificial Intelligence，简称 AI）就是**让机器模仿人类的智能行为**，例如学习、推理、解决问题、理解语言和识别图像。
#
# ---
#
# ### 1. 拆开来看：什么是“人工”和“智能”？
#
# -   **人工**：意思是“人造的”、“非天然的”。它指的是由人类设计、开发和制造出来的系统，而不是自然进化产生的。
# -   **智能**：这是一个更复杂的概念。简单来说，它包括：
#     -   **感知**：看到、听到、感受到（比如识别一张照片里的猫叫）。
#     -   **学习**：从经验或数据中获取知识和技能（比如学会下围棋）。
#     -   **推理**：利用学到的知识进行逻辑判断（比如“如果明天有雨，我就带伞”）。
#     -   **决策**：在多个选项中做出选择（比如导航软件推荐最快的路线）。
#     -   **解决问题**：找到达成目标的方法（比如找到走出迷宫的路）。
#
# **所以，人工智能的目标就是：让计算机系统像人一样，甚至超越人地完成这些需要“智能”才能完成的任务。**
#
# ---
#
# ### 2. 人工智能的两个核心类型
#
# 为了更清楚地理解，通常会把AI分成两大类：
#
# #### A. 弱人工智能 (Narrow AI) —— *我们正在使用的*
#
# -   **定义**：专注于完成**某一个特定领域**的任务。它看起来很聪明，但只能做这一件事。
# -   **特点**：没有真正的意识、情感或跨领域迁移的能力。
# -   **例子**：
#     -   **手机上的语音助手**（Siri，小爱）：只能回答有限问题、设闹钟、查天气。
#     -   **人脸识别**：能认出你是谁，但不会帮你写作文。
#     -   **推荐算法**：抖音、淘宝推荐视频/商品，但不会自己创作剧本。
#     -   **AlphaGo**：下围棋无敌，但如果让它开个门，它什么都不会。
#     -   **ChatGPT**：非常擅长对话和文本生成，但如果你问它“1+1等于几”之外的问题，它也会基于概率“瞎编”，而不是真的理解数学。
#
# **所有你现在能接触到的AI，都是弱人工智能。**
#
# #### B. 强人工智能 (Strong AI / AGI——通用人工智能) —— *我们梦想中的*
#
# -   **定义**：具备与人类**同等或超越人类**的通用智能。它能像人一样学习、理解、适应任何任务。
# -   **特点**：有自我意识、情感、真正的理解和创造力。
# -   **现状**：**目前只存在于科幻小说和电影里**（例如《终结者》的天网、《她》中的萨曼莎）。人类还远远没有实现。
#
# ---
#
# ### 3. 人工智能是如何工作的？（核心原理）
#
# AI不靠“写死的指令”工作（那是普通程序），而是靠 **“学习”**。
#
# 当前最主流的技术是**机器学习**，特别是**深度学习**。
#
# -   **想象一下教一个孩子认猫：**
#     1.  你给他看大量不同猫的照片，同时告诉他“这是猫”。
#     2.  孩子的大脑自动总结出猫的特征（尖耳朵、圆圆的眼睛、胡须等）。
#     3.  下次他看到一只新的动物，如果符合这些特征，他就认出“这是猫”。
#
# -   **人工智能也是这样工作的：**
#     1.  **喂数据**：给计算机成千上万张猫和不是猫的图片。
#     2.  **构建模型**：计算机通过一个巨大的数学公式（神经网络），自动学习分析图片中的像素和模式（比如胡须的形状）。
#     3.  **做出预测**：给它一张从未见过的新图片，它会根据学到的模式，判断：“我有95%的把握这是猫”。
#
# **关键点：AI的能力完全取决于它学到了什么数据。数据越多、质量越好，AI就越聪明。**
#
# ---
#
# ### 4. 一个生活中的例子：使用人工智能订外卖
#
# 1.  **推荐**：当你打开订餐APP，系统会用到**推荐AI**。它根据你过去的点单记录（数据），分析你喜欢的口味（学习），然后推给你可能爱吃的餐厅和菜品（决策）。
# 2.  **搜索**：你搜索“辣”，系统会用**自然语言处理AI**理解你的意图，不只是找出菜名里有“辣”字的菜，还可能包括“麻辣”、“香辣”等相关的。
# 3.  **支付**：你选择“人脸支付”时，**计算机视觉AI**会捕捉你脸部特征，与数据库对比，确认身份。
# 4.  **配送**：饿了么/美团的后台，会用**路径规划AI**，结合实时路况，为骑手计算出最快的取餐和送餐路线。
#
# ### 总结
#
# | 概念 | 简单解释 | 关键点 |
# | :--- | :--- | :--- |
# | **人工智能** | 让机器模仿人类的智能。 | 一个**目标或学科**。 |
# | **机器学习** | 让机器从数据中自动学习，而不是靠人写规则。 | 实现AI的**主流方法**。 |
# | **深度学习** | 使用多层神经网络进行更复杂的学习。 | 机器学习的一个**强大分支**，是当前AI浪潮的主力。 |
# | **大语言模型** | 基于深度学习，专门处理和理解人类语言的大模型（如ChatGPT）。 | 一种**特定类型的深度学习方法**。 |
#
# 希望这个解释能帮你建立起对人工智能的基本理解。它不是一个万能的神，而是一个强大的、基于统计和数据的学习工具。

# %% [markdown]
# # 2、批量调用(batch)
#
# 举例1：一次性接收所有的响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch(messages)

for response in responses:
    print(response)
# Out:
# content='你好！我是 ChatGPT，一个由 OpenAI 训练的 AI 助手。  \n我可以帮你解答问题、写作、翻译、总结、编程、头脑风暴等。\n\n如果你愿意，可以直接告诉我你现在想做什么。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 61, 'prompt_tokens': 10, 'total_tokens': 71, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 39, 'engine_ttlt_ms': 324, 'pre_inference_ms': 82, 'service_tbt_ms': 5, 'service_ttft_ms': 274, 'service_ttlt_ms': 549, 'total_duration_ms': 475, 'user_visible_ttft_ms': 191}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGEjuBJkZ7YUrlxNhMfosn43UvTJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e40c1-8b1c-73b3-bd0f-52397783b655-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 61, 'total_tokens': 71, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='2 + 3 * 5 = **17**' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 15, 'total_tokens': 30, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 4, 'engine_ttft_ms': 29, 'engine_ttlt_ms': 95, 'pre_inference_ms': 189, 'service_tbt_ms': 5, 'service_ttft_ms': 292, 'service_ttlt_ms': 353, 'total_duration_ms': 177, 'user_visible_ttft_ms': 103}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGEjKsHgOe0B9PabKuBQultxLGhv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e40c1-8b1d-7c70-b35d-82af6cedbac5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 15, 'output_tokens': 15, 'total_tokens': 30, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='中国的首都在**北京**。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 11, 'total_tokens': 24, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 4, 'engine_ttft_ms': 28, 'engine_ttlt_ms': 75, 'pre_inference_ms': 89, 'service_tbt_ms': 4, 'service_ttft_ms': 201, 'service_ttlt_ms': 248, 'total_duration_ms': 162, 'user_visible_ttft_ms': 112}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGEjW4sYR1bmbqxJWHHmIgL4c21R', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019e40c1-8b1e-7ee3-a00b-052ad5fe23ce-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 11, 'output_tokens': 13, 'total_tokens': 24, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %% [markdown]
# 举例2：按照完成的顺序接收响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

responses = model.batch_as_completed(messages)

for response in responses:
    print(response)
# Out:
# (2, AIMessage(content='中国的首都是**北京**。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 12, 'prompt_tokens': 11, 'total_tokens': 23, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 4, 'engine_ttft_ms': 35, 'engine_ttlt_ms': 87, 'pre_inference_ms': 115, 'service_tbt_ms': 2, 'service_ttft_ms': 377, 'service_ttlt_ms': 405, 'total_duration_ms': 280, 'user_visible_ttft_ms': 262}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGG0AeKhI9MZOOJPo00OprO4k1yL', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e40c2-c2d8-73a1-b330-68ce120ab7dd-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 12, 'total_tokens': 23, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))
# (1, AIMessage(content='2 + 3 * 5 = 17', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 15, 'total_tokens': 29, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 41, 'engine_ttlt_ms': 105, 'pre_inference_ms': 93, 'service_tbt_ms': 4, 'service_ttft_ms': 301, 'service_ttlt_ms': 347, 'total_duration_ms': 263, 'user_visible_ttft_ms': 207}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGG1WLGUWZcIGCPYgUJEokvmY2m9', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e40c2-c2d8-73a1-b330-68b6a37ebc1a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 15, 'output_tokens': 14, 'total_tokens': 29, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))
# (0, AIMessage(content='你好！我是 ChatGPT，一个由 OpenAI 训练的人工智能助手。  \n我可以帮你回答问题、写作、翻译、总结、编程、头脑风暴等。\n\n如果你愿意，也可以直接告诉我你现在想做什么。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 60, 'prompt_tokens': 10, 'total_tokens': 70, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 44, 'engine_ttlt_ms': 367, 'pre_inference_ms': 194, 'service_tbt_ms': 6, 'service_ttft_ms': 666, 'service_ttlt_ms': 1035, 'total_duration_ms': 844, 'user_visible_ttft_ms': 472}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DhGG0WYOyXUOtmmSQFNIFST05jXUp', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019e40c2-c2d6-7ca2-ac64-e4f24820a1cf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 60, 'total_tokens': 70, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))

# %% [markdown]
# 举例3：性能对比
#
# 使用batch

# %%
# 准备多个输入
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

# ✅ 批量调用（高效）
import time

start = time.time()
responses = model.batch(inputs)
batch_time = time.time() - start

print("批量调用结果：")
for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")
print(f"耗时: {batch_time:.2f}秒\n")
# Out:
# 批量调用结果：
# 1. “Spring has come.”
# 2. “夏天很热” can be translated into English as:
#
# **“Summer is very hot.”**
# 3. “秋天落叶”可以翻译成英文 **“autumn leaves”**，也可以说 **“fall leaves”**（美式英语里更常用）。
#
# 如果你想表达“秋天里的落叶”这个意思，**“fallen leaves in autumn”** 也很自然。
# 4. “Winter is snowy.”
# If you mean the more natural phrase, it is: **“It snows in winter.”**
# 耗时: 2.24秒

# %% [markdown]
# 作为对比，演示循环调用invoke()

# %%
# ❌ 循环调用（低效，仅用于对比）
inputs = [
    "翻译成英文：春天来了",
    "翻译成英文：夏天很热",
    "翻译成英文：秋天落叶",
    "翻译成英文：冬天下雪"
]

start = time.time()
loop_responses = []
for inp in inputs:
    response = model.invoke(inp)
    loop_responses.append(response)
loop_time = time.time() - start

for i, response in enumerate(responses):
    print(f"{i+1}. {response.content}")

print(f"循环调用耗时: {loop_time:.2f}秒")

print(f"批量调用节省: {((loop_time - batch_time) / loop_time * 100):.1f}%")
# Out:
# 1. “Spring has come.”
# 2. “夏天很热” can be translated into English as:
#
# **“Summer is very hot.”**
# 3. “秋天落叶”可以翻译成英文 **“autumn leaves”**，也可以说 **“fall leaves”**（美式英语里更常用）。
#
# 如果你想表达“秋天里的落叶”这个意思，**“fallen leaves in autumn”** 也很自然。
# 4. “Winter is snowy.”
# If you mean the more natural phrase, it is: **“It snows in winter.”**
# 循环调用耗时: 5.10秒
# 批量调用节省: 56.2%
